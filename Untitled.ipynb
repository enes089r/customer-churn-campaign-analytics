# %%
import pandas as pd
import kagglehub
import os

path = kagglehub.dataset_download("frtgnn/dunnhumby-the-complete-journey")

tx = pd.read_csv(os.path.join(path, "transaction_data.csv"))

tx.columns = tx.columns.str.lower()

tx.head()
# Out:
#    household_key    basket_id  day  product_id  quantity  sales_value  \
# 0           2375  26984851472    1     1004906         1         1.39
# 1           2375  26984851472    1     1033142         1         0.82
# 2           2375  26984851472    1     1036325         1         0.99
# 3           2375  26984851472    1     1082185         1         1.21
# 4           2375  26984851472    1     8160430         1         1.50
#
#    store_id  retail_disc  trans_time  week_no  coupon_disc  coupon_match_disc
# 0       364        -0.60        1631        1          0.0                0.0
# 1       364         0.00        1631        1          0.0                0.0
# 2       364        -0.30        1631        1          0.0                0.0
# 3       364         0.00        1631        1          0.0                0.0
# 4       364        -0.39        1631        1          0.0                0.0

# %%
import numpy as np

# %%
# find the actual day in data
referance_day = tx.day.max()
referance_day
# Out:
# np.int64(711)

# %%
rfm = tx.groupby('household_key').agg(
    last_day = ("day" , "max"),
    frequency = ("basket_id", "nunique"),
    monetary = ("sales_value" , "sum")
    )

# %%
print(rfm.shape, rfm.monetary.sum(), tx.sales_value.sum())
# Out:
# (2500, 3) 8057463.08 8057463.08

# %%
referance_day - rfm.last_day
# Out:
# household_key
# 1        5
# 2       43
# 3        8
# 4       84
# 5        8
#         ..
# 2496    28
# 2497    11
# 2498     1
# 2499     2
# 2500     3
# Name: last_day, Length: 2500, dtype: int64

# %%
(referance_day - rfm.last_day).value_counts()
# Out:
# last_day
# 0      367
# 1      262
# 2      194
# 3      157
# 6      117
#       ...
# 111      1
# 270      1
# 108      1
# 230      1
# 168      1
# Name: count, Length: 200, dtype: int64

# %%
rfm["recency"] = referance_day - rfm.last_day

# %%
rfm
# Out:
#                last_day  frequency  monetary  recency
# household_key
# 1                   706         86   4330.16        5
# 2                   668         45   1954.34       43
# 3                   703         47   2653.21        8
# 4                   627         30   1200.11       84
# 5                   703         40    779.06        8
# ...                 ...        ...       ...      ...
# 2496                683         63   4339.66       28
# 2497                700        221   7111.98       11
# 2498                710        172   2601.60        1
# 2499                709         90   3394.07        2
# 2500                708        113   5486.16        3
#
# [2500 rows x 4 columns]

# %% [markdown]
# ### stage 4

# %%
rfm.recency.describe()
# Out:
# count    2500.000000
# mean       25.574000
# std        62.790655
# min         0.000000
# 25%         1.000000
# 50%         6.000000
# 75%        20.000000
# max       657.000000
# Name: recency, dtype: float64

# %%
rfm.frequency.describe()
# Out:
# count    2500.000000
# mean      110.593600
# std       115.669368
# min         1.000000
# 25%        39.000000
# 50%        79.000000
# 75%       142.250000
# max      1300.000000
# Name: frequency, dtype: float64

# %%
rfm.monetary.describe()
# Out:
# count     2500.000000
# mean      3222.985232
# std       3349.026076
# min          8.170000
# 25%        970.740000
# 50%       2157.750000
# 75%       4413.320000
# max      38319.790000
# Name: monetary, dtype: float64

# %% [markdown]
# ### stage 5

# %%
rfm.head()
# Out:
#                last_day  frequency  monetary  recency
# household_key
# 1                   706         86   4330.16        5
# 2                   668         45   1954.34       43
# 3                   703         47   2653.21        8
# 4                   627         30   1200.11       84
# 5                   703         40    779.06        8

# %%
r_score_conditions = [
    rfm["recency"] <= 7,
    rfm["recency"] <= 14,
    rfm["recency"] <= 30,
    rfm["recency"] <= 60
]
values = [5, 4, 3, 2]

rfm["r_score"] = np.select(r_score_conditions, values, default = 1)

# %%
rfm["r_score"].value_counts()
# Out:
# r_score
# 5    1407
# 3     338
# 4     301
# 1     255
# 2     199
# Name: count, dtype: int64

# %%
rfm["f_score"] = pd.qcut(rfm["frequency"], q=5, labels=[1, 2, 3, 4, 5]).astype(int)

# %%
rfm["m_score"] = pd.qcut(rfm["monetary"], q=5, labels=[1, 2, 3, 4, 5]).astype(int)

# %%
rfm
# Out:
#                last_day  frequency  monetary  recency  r_score  f_score  \
# household_key
# 1                   706         86   4330.16        5        5        3
# 2                   668         45   1954.34       43        2        2
# 3                   703         47   2653.21        8        4        2
# 4                   627         30   1200.11       84        1        1
# 5                   703         40    779.06        8        4        2
# ...                 ...        ...       ...      ...      ...      ...
# 2496                683         63   4339.66       28        3        3
# 2497                700        221   7111.98       11        4        5
# 2498                710        172   2601.60        1        5        5
# 2499                709         90   3394.07        2        5        3
# 2500                708        113   5486.16        3        5        4
#
#                m_score
# household_key
# 1                    4
# 2                    3
# 3                    3
# 4                    2
# 5                    2
# ...                ...
# 2496                 4
# 2497                 5
# 2498                 3
# 2499                 4
# 2500                 5
#
# [2500 rows x 7 columns]

# %%
rfm["f_score"].value_counts()
# Out:
# f_score
# 2    505
# 1    502
# 3    499
# 5    498
# 4    496
# Name: count, dtype: int64

# %%
rfm["m_score"].value_counts()
# Out:
# m_score
# 4    500
# 3    500
# 2    500
# 5    500
# 1    500
# Name: count, dtype: int64

# %%
rfm[["frequency", "monetary"]].corr(method="spearman")
# value_score method usable because there is a strong correlation between frequency and monetary
# Out:
#            frequency  monetary
# frequency   1.000000  0.845523
# monetary    0.845523  1.000000

# %%
pd.crosstab(rfm["f_score"], rfm["m_score"])
# it means most households sit on the diagonal. frequent shoppers are also high spenders.
# Out:
# m_score    1    2    3    4    5
# f_score
# 1        362  113   23    4    0
# 2        116  233  118   35    3
# 3         20  114  190  136   39
# 4          2   36  125  201  132
# 5          0    4   44  124  326

# %%
rfm["value_score"] = (rfm.f_score + rfm.m_score) / 2

# %%
rfm
# Out:
#                last_day  frequency  monetary  recency  r_score  f_score  \
# household_key
# 1                   706         86   4330.16        5        5        3
# 2                   668         45   1954.34       43        2        2
# 3                   703         47   2653.21        8        4        2
# 4                   627         30   1200.11       84        1        1
# 5                   703         40    779.06        8        4        2
# ...                 ...        ...       ...      ...      ...      ...
# 2496                683         63   4339.66       28        3        3
# 2497                700        221   7111.98       11        4        5
# 2498                710        172   2601.60        1        5        5
# 2499                709         90   3394.07        2        5        3
# 2500                708        113   5486.16        3        5        4
#
#                m_score  value_score
# household_key
# 1                    4          3.5
# 2                    3          2.5
# 3                    3          2.5
# 4                    2          1.5
# 5                    2          2.0
# ...                ...          ...
# 2496                 4          3.5
# 2497                 5          5.0
# 2498                 3          4.0
# 2499                 4          3.5
# 2500                 5          4.5
#
# [2500 rows x 8 columns]

# %%
segment_conditions = [
    (rfm.r_score >= 4) & (rfm.value_score >= 4),
    (rfm.r_score >= 4) & (rfm.value_score >= 3),
    (rfm.r_score <= 3) & (rfm.value_score >= 3),
    (rfm.r_score <= 2) & (rfm.value_score < 3),
]

segments = ["High-Value Active","Mid-Value Active","High-Value Lapsing","Low-Value Lapsed"]
rfm["segments"] = np.select(segment_conditions, segments, default = "Low-Value Active")

# %%
rfm
# Out:
#                last_day  frequency  monetary  recency  r_score  f_score  \
# household_key
# 1                   706         86   4330.16        5        5        3
# 2                   668         45   1954.34       43        2        2
# 3                   703         47   2653.21        8        4        2
# 4                   627         30   1200.11       84        1        1
# 5                   703         40    779.06        8        4        2
# ...                 ...        ...       ...      ...      ...      ...
# 2496                683         63   4339.66       28        3        3
# 2497                700        221   7111.98       11        4        5
# 2498                710        172   2601.60        1        5        5
# 2499                709         90   3394.07        2        5        3
# 2500                708        113   5486.16        3        5        4
#
#                m_score  value_score            segments
# household_key
# 1                    4          3.5    Mid-Value Active
# 2                    3          2.5    Low-Value Lapsed
# 3                    3          2.5    Low-Value Active
# 4                    2          1.5    Low-Value Lapsed
# 5                    2          2.0    Low-Value Active
# ...                ...          ...                 ...
# 2496                 4          3.5  High-Value Lapsing
# 2497                 5          5.0   High-Value Active
# 2498                 3          4.0   High-Value Active
# 2499                 4          3.5    Mid-Value Active
# 2500                 5          4.5   High-Value Active
#
# [2500 rows x 9 columns]

# %%
rfm["segments"].value_counts()
# Out:
# segments
# High-Value Active     782
# Low-Value Active      733
# Mid-Value Active      418
# Low-Value Lapsed      372
# High-Value Lapsing    195
# Name: count, dtype: int64

# %%
segment_profile   = rfm.groupby('segments').agg(
    households    = ('monetary', 'count'),
    avg_recency   = ('recency', 'mean'),
    avg_monetary  = ('monetary','mean'),
    avg_frequency = ('frequency', 'mean'),
    total_revenue = ('monetary','sum')
)

# %%
segment_profile
# Out:
#                     households  avg_recency  avg_monetary  avg_frequency  \
# segments
# High-Value Active          782     2.855499   6665.382532     220.631714
# High-Value Lapsing         195    44.543590   3655.451231     119.774359
# Low-Value Active           733     9.899045   1085.158990      42.567531
# Low-Value Lapsed           372   118.287634    666.658629      25.658602
# Mid-Value Active           418     4.203349   2605.029665      95.327751
#
#                     total_revenue
# segments
# High-Value Active      5212329.14
# High-Value Lapsing      712812.99
# Low-Value Active        795421.54
# Low-Value Lapsed        247997.01
# Mid-Value Active       1088902.40
